# %%
from sqlalchemy import Column, ForeignKey, Float, \
    Integer, String, UnicodeText, DateTime, create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship

Base = declarative_base()

# %%
class Project(Base):
    __tablename__ = 'project'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(UnicodeText, nullable=False)
    created_date = Column(DateTime, nullable=False)
    description = Column(UnicodeText, nullable=False)

# %%
class Cell(Base):
    __tablename__ = 'cell'

    id = Column(Integer, primary_key=True, autoincrement=True)
    cell_type_id = Column(Integer, ForeignKey('cell_type.id'), nullable=False)
    created_date = Column(DateTime, nullable=False)
    
    cell_type = relationship("CellType", foreign_keys=[cell_type_id])

class CellType(Base):
    __tablename__ = 'cell_type'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(UnicodeText, nullable=False)
    created_date = Column(DateTime, nullable=False)
    vendor = Column(UnicodeText, nullable=False)
    vendor_batch = Column(UnicodeText, nullable=False)
    
    electrolyte_id = Column(Integer, ForeignKey('electrolyte.id'), nullable=False)
    positive_electrode_id = Column(Integer, ForeignKey('positive_electrode.id'), nullable=False)
    separator_id = Column(Integer, ForeignKey('separator.id'), nullable=False)
    negative_electrode_id = Column(Integer, ForeignKey('negative_electrode.id'), nullable=False)

    electrolyte = relationship("Electrolyte", foreign_keys=[electrolyte_id])
    positive_electrode = relationship("PositiveElectrode", foreign_keys=[positive_electrode_id])
    separator = relationship("Separator", foreign_keys=[separator_id])
    negative_electrode = relationship("NegativeElectrode", foreign_keys=[negative_electrode_id])

# %%
class SeparatorComponent(Base):
    __tablename__ = 'separator_component'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    created_date = Column(DateTime, nullable=False)
    
    component = Column(UnicodeText, nullable=False)
    name = Column(UnicodeText, nullable=False)
    smiles = Column(UnicodeText)

class SeparatorConcentration(Base):
    __tablename__ = 'separator_concentration'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    component_id = Column(Integer, ForeignKey('separator_component.id'), nullable=False)
    concentration = Column(Float, nullable=False)

    component = relationship("SeparatorComponent", foreign_keys=[component_id])
    
class Separator(Base):
    __tablename__ = 'separator'

    id = Column(Integer, primary_key=True, autoincrement=True)    
    cell_id = Column(Integer, ForeignKey('cell.id'), nullable=False)
    separator_id = Column(Integer, ForeignKey('separator_concentration.id'), nullable=False)
    
    cell = relationship("Cell", foreign_keys=[cell_id])
    separator = relationship("SeparatorConcentration", foreign_keys=[separator_id])

# %%
class ElectrolyteComponent(Base):
    __tablename__ = 'electrolyte_component'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    created_date = Column(DateTime, nullable=False)
    
    component = Column(UnicodeText, nullable=False)
    name = Column(UnicodeText, nullable=False)
    smiles = Column(UnicodeText)

class ElectroltyeConcentration(Base):
    __tablename__ = 'electrolyte_concentration'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    component_id = Column(Integer, ForeignKey('electrolyte_component.id'), nullable=False)
    concentration = Column(Float, nullable=False)

    component = relationship("ElectrolyteComponent", foreign_keys=[component_id])
    
class Electrolyte(Base):
    __tablename__ = 'electrolyte'

    id = Column(Integer, primary_key=True, autoincrement=True)    
    cell_id = Column(Integer, ForeignKey('cell.id'), nullable=False)
    electrolyte_id = Column(Integer, ForeignKey('electrolyte_concentration.id'), nullable=False)
    
    cell = relationship("Cell", foreign_keys=[cell_id])
    electrolyte = relationship("ElectroltyeConcentration", foreign_keys=[electrolyte_id])

# %%
class ElectrodeComponent(Base):
    __tablename__ = 'electrode_component'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    created_date = Column(DateTime, nullable=False)
    
    component = Column(UnicodeText, nullable=False)
    name = Column(UnicodeText, nullable=False)
    smiles = Column(UnicodeText)

class PositiveElectrodeConcentration(Base):
    __tablename__ = 'positive_electrode_concentration'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    component_id = Column(Integer, ForeignKey('electrode_component.id'), nullable=False)
    concentration = Column(Float, nullable=False)

    component = relationship("ElectrodeComponent", foreign_keys=[component_id])
    
class PositiveElectrode(Base):
    __tablename__ = 'positive_electrode'

    id = Column(Integer, primary_key=True, autoincrement=True)    
    cell_id = Column(Integer, ForeignKey('cell.id'), nullable=False)
    positive_electrode_id = Column(Integer, ForeignKey('positive_electrode_concentration.id'), nullable=False)
    
    cell = relationship("Cell", foreign_keys=[cell_id])
    positive_electrode = relationship("PositiveElectrodeConcentration", foreign_keys=[positive_electrode_id])

# %%
class NegativeElectrodeConcentration(Base):
    __tablename__ = 'negative_electrode_concentration'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    component_id = Column(Integer, ForeignKey('electrode_component.id'), nullable=False)
    concentration = Column(Float, nullable=False)

    component = relationship("ElectrodeComponent", foreign_keys=[component_id])
    
class NegativeElectrode(Base):
    __tablename__ = 'negative_electrode'

    id = Column(Integer, primary_key=True, autoincrement=True)    
    cell_id = Column(Integer, ForeignKey('cell.id'), nullable=False)
    positive_electrode_id = Column(Integer, ForeignKey('negative_electrode_concentration.id'), nullable=False)
    
    cell = relationship("Cell", foreign_keys=[cell_id])
    positive_electrode = relationship("NegativeElectrodeConcentration", foreign_keys=[positive_electrode_id])

# %%
class MeasurementType(Base):
    __tablename__ = 'measurement_type'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(UnicodeText, nullable=False)
    table_name = Column(String(32), nullable=False)

# %%
class Measurement(Base):
    __tablename__ = 'measurement'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    project_id = Column(Integer, ForeignKey('project.id'), nullable=False)
    cell_id = Column(Integer, ForeignKey('cell.id'), nullable=False)
    measurement_type_id = Column(Integer, ForeignKey('measurement_type.id'), nullable=False)

    project = relationship("Project", foreign_keys=[project_id])
    cell = relationship('Cell', foreign_keys=[cell_id])
    measurement_type = relationship('MeasurementType', foreign_keys=[measurement_type_id])

# %%
class VirtualProject(Base):
    __tablename__ = 'virtual_project'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(UnicodeText, nullable=False)
    created_date = Column(DateTime, nullable=False)
    description = Column(UnicodeText, nullable=False)

# %%
class VirtualProjectCatalog(Base):
    __tablename__ = 'virtual_project_catalog'
    
    virtual_project_id = Column(Integer, ForeignKey('virtual_project.id'), 
                                nullable=False, primary_key=True)
    measurement_id = Column(Integer, ForeignKey('measurement.id'), 
                            nullable=False, primary_key=True)
    
    measurement = relationship('Measurement', foreign_keys=[measurement_id])

# %%
class CyclerInstrument(Base):
    __tablename__ = 'cycler_instrument'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(String(32), nullable=False)
    model = Column(String(32), nullable=False)

# %%
class Cycling(Base):
    __tablename__ = 'cycling'
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    
    cell_id = Column(Integer, ForeignKey('cell.id'), nullable=False)
    project_id = Column(Integer, ForeignKey('project.id'), nullable=False)
    temperature_K = Column(Float)
    data_table_name = Column(String(32), nullable=False)
    created_date = Column(DateTime, nullable=False)
    raw_data__filename = Column(String(32))
    cycler_instrument_id = Column(Integer, ForeignKey('cycler_instrument.id'), nullable=False)

# %%
db = create_engine('sqlite:///batters_hit.db')
db.echo = True
con = db.connect()
# Out:
# 2019-10-15 17:37:11,961 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-10-15 17:37:11,961 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,962 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-10-15 17:37:11,963 INFO sqlalchemy.engine.base.Engine ()

# %%
Base.metadata.create_all(db)
con.close()
# Out:
# 2019-10-15 17:37:11,968 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("project")
# 2019-10-15 17:37:11,969 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,970 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("project")
# 2019-10-15 17:37:11,971 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,972 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("cell")
# 2019-10-15 17:37:11,972 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,973 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("cell")
# 2019-10-15 17:37:11,974 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,974 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("cell_type")
# 2019-10-15 17:37:11,974 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,975 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("cell_type")
# 2019-10-15 17:37:11,976 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,977 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("separator_component")
# 2019-10-15 17:37:11,977 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,978 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("separator_component")
# 2019-10-15 17:37:11,978 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,979 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("separator_concentration")
# 2019-10-15 17:37:11,980 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,981 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("separator_concentration")
# 2019-10-15 17:37:11,981 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,982 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("separator")
# 2019-10-15 17:37:11,983 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,983 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("separator")
# 2019-10-15 17:37:11,984 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,984 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("electrolyte_component")
# 2019-10-15 17:37:11,985 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,986 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("electrolyte_component")
# 2019-10-15 17:37:11,987 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,988 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("electrolyte_concentration")
# 2019-10-15 17:37:11,988 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,989 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("electrolyte_concentration")
# 2019-10-15 17:37:11,989 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,991 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("electrolyte")
# 2019-10-15 17:37:11,991 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,992 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("electrolyte")
# 2019-10-15 17:37:11,992 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,993 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("electrode_component")
# 2019-10-15 17:37:11,993 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,994 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("electrode_component")
# 2019-10-15 17:37:11,994 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,995 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("positive_electrode_concentration")
# 2019-10-15 17:37:11,996 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,997 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("positive_electrode_concentration")
# 2019-10-15 17:37:11,998 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:11,999 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("positive_electrode")
# 2019-10-15 17:37:11,999 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,000 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("positive_electrode")
# 2019-10-15 17:37:12,001 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,002 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("negative_electrode_concentration")
# 2019-10-15 17:37:12,003 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,004 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("negative_electrode_concentration")
# 2019-10-15 17:37:12,004 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,005 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("negative_electrode")
# 2019-10-15 17:37:12,005 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,006 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("negative_electrode")
# 2019-10-15 17:37:12,007 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,008 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("measurement_type")
# 2019-10-15 17:37:12,008 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,009 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("measurement_type")
# 2019-10-15 17:37:12,009 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,010 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("measurement")
# 2019-10-15 17:37:12,011 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,011 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("measurement")
# 2019-10-15 17:37:12,012 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,012 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("virtual_project")
# 2019-10-15 17:37:12,014 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,014 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("virtual_project")
# 2019-10-15 17:37:12,015 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,015 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("virtual_project_catalog")
# 2019-10-15 17:37:12,016 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,017 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("virtual_project_catalog")
# 2019-10-15 17:37:12,018 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,019 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("cycler_instrument")
# 2019-10-15 17:37:12,019 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,020 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("cycler_instrument")
# 2019-10-15 17:37:12,020 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,021 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("cycling")
# 2019-10-15 17:37:12,022 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,022 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("cycling")
# 2019-10-15 17:37:12,023 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,026 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE project (
# 	id INTEGER NOT NULL,
# 	name TEXT NOT NULL,
# 	created_date DATETIME NOT NULL,
# 	description TEXT NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2019-10-15 17:37:12,026 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,030 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,031 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE cell (
# 	id INTEGER NOT NULL,
# 	cell_type_id INTEGER NOT NULL,
# 	created_date DATETIME NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(cell_type_id) REFERENCES cell_type (id)
# )
#
#
# 2019-10-15 17:37:12,031 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,033 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,034 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE cell_type (
# 	id INTEGER NOT NULL,
# 	name TEXT NOT NULL,
# 	created_date DATETIME NOT NULL,
# 	vendor TEXT NOT NULL,
# 	vendor_batch TEXT NOT NULL,
# 	electrolyte_id INTEGER NOT NULL,
# 	positive_electrode_id INTEGER NOT NULL,
# 	separator_id INTEGER NOT NULL,
# 	negative_electrode_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(electrolyte_id) REFERENCES electrolyte (id),
# 	FOREIGN KEY(positive_electrode_id) REFERENCES positive_electrode (id),
# 	FOREIGN KEY(separator_id) REFERENCES separator (id),
# 	FOREIGN KEY(negative_electrode_id) REFERENCES negative_electrode (id)
# )
#
#
# 2019-10-15 17:37:12,035 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,037 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,038 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE separator_component (
# 	id INTEGER NOT NULL,
# 	created_date DATETIME NOT NULL,
# 	component TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	smiles TEXT,
# 	PRIMARY KEY (id)
# )
# 2019-10-15 17:37:12,039 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,040 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,041 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE separator_concentration (
# 	id INTEGER NOT NULL,
# 	component_id INTEGER NOT NULL,
# 	concentration FLOAT NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(component_id) REFERENCES separator_component (id)
# )
#
#
# 2019-10-15 17:37:12,041 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,043 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,044 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE separator (
# 	id INTEGER NOT NULL,
# 	cell_id INTEGER NOT NULL,
# 	separator_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(cell_id) REFERENCES cell (id),
# 	FOREIGN KEY(separator_id) REFERENCES separator_concentration (id)
# )
#
#
# 2019-10-15 17:37:12,044 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,046 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,047 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE electrolyte_component (
# 	id INTEGER NOT NULL,
# 	created_date DATETIME NOT NULL,
# 	component TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	smiles TEXT,
# 	PRIMARY KEY (id)
# )
#
#
# 2019-10-15 17:37:12,047 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,049 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,050 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE electrolyte_concentration (
# 	id INTEGER NOT NULL,
# 	component_id INTEGER NOT NULL,
# 	concentration FLOAT NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(component_id) REFERENCES electrolyte_component (id)
# )
#
#
# 2019-10-15 17:37:12,051 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,053 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,054 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE electrolyte (
# 	id INTEGER NOT NULL,
# 	cell_id INTEGER NOT NULL,
# 	electrolyte_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(cell_id) REFERENCES cell (id),
# 	FOREIGN KEY(electrolyte_id) REFERENCES electrolyte_concentration (id)
# )
#
#
# 2019-10-15 17:37:12,055 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,056 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,057 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE electrode_component (
# 	id INTEGER NOT NULL,
# 	created_date DATETIME NOT NULL,
# 	component TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	smiles TEXT,
# 	PRIMARY KEY (id)
# )
#
#
# 2019-10-15 17:37:12,058 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,060 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,061 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE positive_electrode_concentration (
# 	id INTEGER NOT NULL,
# 	component_id INTEGER NOT NULL,
# 	concentration FLOAT NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(component_id) REFERENCES electrode_component (id)
# )
#
#
# 2019-10-15 17:37:12,061 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,063 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,064 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE positive_electrode (
# 	id INTEGER NOT NULL,
# 	cell_id INTEGER NOT NULL,
# 	positive_electrode_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(cell_id) REFERENCES cell (id),
# 	FOREIGN KEY(positive_electrode_id) REFERENCES positive_electrode_concentration (id)
# )
#
#
# 2019-10-15 17:37:12,064 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,066 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,067 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE negative_electrode_concentration (
# 	id INTEGER NOT NULL,
# 	component_id INTEGER NOT NULL,
# 	concentration FLOAT NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(component_id) REFERENCES electrode_component (id)
# )
#
#
# 2019-10-15 17:37:12,068 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,069 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,070 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE negative_electrode (
# 	id INTEGER NOT NULL,
# 	cell_id INTEGER NOT NULL,
# 	positive_electrode_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(cell_id) REFERENCES cell (id),
# 	FOREIGN KEY(positive_electrode_id) REFERENCES negative_electrode_concentration (id)
# )
#
#
# 2019-10-15 17:37:12,071 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,072 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,073 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE measurement_type (
# 	id INTEGER NOT NULL,
# 	name TEXT NOT NULL,
# 	table_name VARCHAR(32) NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2019-10-15 17:37:12,074 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,076 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,077 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE measurement (
# 	id INTEGER NOT NULL,
# 	project_id INTEGER NOT NULL,
# 	cell_id INTEGER NOT NULL,
# 	measurement_type_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(project_id) REFERENCES project (id),
# 	FOREIGN KEY(cell_id) REFERENCES cell (id),
# 	FOREIGN KEY(measurement_type_id) REFERENCES measurement_type (id)
# )
#
#
# 2019-10-15 17:37:12,077 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,079 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,080 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE virtual_project (
# 	id INTEGER NOT NULL,
# 	name TEXT NOT NULL,
# 	created_date DATETIME NOT NULL,
# 	description TEXT NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2019-10-15 17:37:12,080 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,082 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,083 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE virtual_project_catalog (
# 	virtual_project_id INTEGER NOT NULL,
# 	measurement_id INTEGER NOT NULL,
# 	PRIMARY KEY (virtual_project_id, measurement_id),
# 	FOREIGN KEY(virtual_project_id) REFERENCES virtual_project (id),
# 	FOREIGN KEY(measurement_id) REFERENCES measurement (id)
# )
#
#
# 2019-10-15 17:37:12,084 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,086 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,087 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE cycler_instrument (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(32) NOT NULL,
# 	model VARCHAR(32) NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2019-10-15 17:37:12,087 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,089 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-10-15 17:37:12,090 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE cycling (
# 	id INTEGER NOT NULL,
# 	cell_id INTEGER NOT NULL,
# 	project_id INTEGER NOT NULL,
# 	"temperature_K" FLOAT,
# 	data_table_name VARCHAR(32) NOT NULL,
# 	created_date DATETIME NOT NULL,
# 	raw_data__filename VARCHAR(32),
# 	cycler_instrument_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(cell_id) REFERENCES cell (id),
# 	FOREIGN KEY(project_id) REFERENCES project (id),
# 	FOREIGN KEY(cycler_instrument_id) REFERENCES cycler_instrument (id)
# )
#
#
# 2019-10-15 17:37:12,090 INFO sqlalchemy.engine.base.Engine ()
# 2019-10-15 17:37:12,092 INFO sqlalchemy.engine.base.Engine COMMIT
